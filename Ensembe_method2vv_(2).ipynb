# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from os import makedirs, path
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import pandas as pd
import os

#Importing libraries
import warnings
warnings.filterwarnings('ignore')

import numpy as np
import torch
from torch import nn, optim
from torchvision import datasets, transforms
from torch.utils.data import DataLoader, random_split
from tqdm import tqdm
import torch.nn.functional as F
import cv2

# %%
from google.colab import files
files.upload()


# Use makedirs with exist_ok, it's available in older versions and works like mkdir with exist_ok
makedirs(name=path.expanduser('~/.kaggle'), mode=0o777, exist_ok=True)

# Continue with your code...
# !cp kaggle.json ~/.kaggle/

#permission
# !chmod 600 ~/.kaggle/kaggle.json


! kaggle datasets download murtozalikhon/brain-tumor-multimodal-image-ct-and-mri
! unzip /content/brain-tumor-multimodal-image-ct-and-mri.zip
# Out:
#      <input type="file" id="files-b1d77040-2f2a-4109-8b9b-90c61742cf67" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-b1d77040-2f2a-4109-8b9b-90c61742cf67">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
root = "/content/Dataset"
transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.Grayscale(num_output_channels=1),
    transforms.ToTensor(),
])
# Calculate mean and std for your dataset
dataset = datasets.ImageFolder(root=root,transform=transform )

loader = torch.utils.data.DataLoader(dataset, batch_size=64, shuffle=False)
mean = 0.
std = 0.
for images, _ in loader:
    batch_samples = images.size(0)
    images = images.view(batch_samples, images.size(1), -1)
    mean += images.mean(2).sum(0)
    std += images.std(2).sum(0)

mean /= len(loader.dataset)
std /= len(loader.dataset)

print(f"Mean: {mean.item()}, Std: {std.item()}")
# Out:
# Mean: 0.2234388291835785, Std: 0.24283750355243683

# %%
normalize=transforms.Normalize(mean=mean.item(),std=std.item())
transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.Grayscale(num_output_channels=1),
    transforms.ToTensor(),
    normalize])

random_augmentation = transforms.RandomApply(nn.ModuleList([
    transforms.RandomHorizontalFlip(),
    transforms.RandomVerticalFlip(),
    transforms.RandomPerspective(),
    transforms.RandomRotation((60, 300)),
    transforms.RandomErasing(scale=(0.01, 0.1), p=0.3),
    transforms.ColorJitter(brightness=0.2, contrast=0.2, saturation=0.2),
    transforms.GaussianBlur(kernel_size=(5, 9), sigma=(0.1, 5))
]))

dataset = datasets.ImageFolder(root=root, transform=transform)
from sklearn.model_selection import train_test_split

# Get targets (labels) from the dataset
targets = [target for _, target in dataset]

# Split into train and remaining (val + test)
train_indices, remaining_indices, _, _ = train_test_split(
    range(len(dataset)), targets, test_size=0.2, stratify=targets, random_state=42
)

# Split remaining into validation and test
val_indices, test_indices, _, _ = train_test_split(
    remaining_indices, [targets[i] for i in remaining_indices], test_size=0.5, stratify=[targets[i] for i in remaining_indices], random_state=42
)

# Create subsets
train_dataset = torch.utils.data.Subset(dataset, train_indices)
val_dataset = torch.utils.data.Subset(dataset, val_indices)
test_dataset = torch.utils.data.Subset(dataset, test_indices)

# Convert Train_data to Agumented Dataset
class AugmentedDataset(torch.utils.data.Dataset):
    def __init__(self, dataset, transform):
        self.dataset = dataset
        self.transform = transform

    def __getitem__(self, index):
        image, label = self.dataset[index]
        image = self.transform(image)
        return image, label

    def __len__(self):
        return len(self.dataset)

# wrap datasets in Dataloder
train_loader = DataLoader(AugmentedDataset(train_dataset, random_augmentation), batch_size=32, shuffle=False)
val_loader = DataLoader(val_dataset, batch_size=32, shuffle=False)
test_loader = DataLoader(test_dataset, batch_size=32, shuffle=False)

print("Training set size:", len(train_dataset))
print("Validation set size:", len(val_dataset))
print("Testing set size:", len(test_dataset))
# Out:
# Training set size: 7694
# Validation set size: 962
# Testing set size: 962

# %%
import timm
import torch.nn as nn
from torchvision import models

# %%
class EnsembleModel(nn.Module):
  def __init__(self, models, ensemble_method="weighted", weights=None):
    super(EnsembleModel, self).__init__()
    self.models = nn.ModuleList(models)
    self.ensemble_method = ensemble_method
    self.weights = weights

    # Initialize weights if not provided for the "weighted" method
    if self.ensemble_method == "weighted" and self.weights is None:
        self.weights = nn.Parameter(torch.ones(len(self.models)) / len(self.models)) #Fixed nn.Paramter to nn.Parameter

  def forward(self, x):
    outputs = [model(x) for model in self.models]
    if self.ensemble_method == "simple":
        return torch.mean(torch.stack(outputs), dim=0)
    elif self.ensemble_method == "weighted":
        weights = F.softmax(self.weights, dim=0)
        return torch.sum(torch.stack([output * weight for output, weight in zip(outputs, weights)]), dim=0)
    elif self.ensemble_method == "geometric":
        # Convert logits to probabilities
        probs = [F.softmax(out, dim=1) for out in outputs]
        geometric_mean = torch.exp(torch.mean(torch.stack([torch.log(p + 1e-9) for p in probs]), dim=0))
        return torch.log(geometric_mean)
    else:
        raise ValueError("Invalid ensemble method.")

# %%
# Check if GPU is available, otherwise use CPU
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
model1=timm.create_model('vit_base_patch16_224',pretrained=True).to(device)
# Access and modify the first convolutional layer of model1
model1.patch_embed.proj = nn.Conv2d(1, 768, kernel_size=(16, 16), stride=(16, 16)).to(device)
model2=timm.create_model('efficientnet_b0',pretrained=True).to(device)
#Change the first layer of model2 to take in a single channel
model2.conv_stem=nn.Conv2d(1,32,kernel_size=(3,3),stride=(2,2),padding=(1,1),bias=False).to(device)
# Out:
# model.safetensors:   0%|          | 0.00/346M [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/21.4M [00:00<?, ?B/s]
# Downloading: "https://download.pytorch.org/models/resnet18-f37072fd.pth" to /root/.cache/torch/hub/checkpoints/resnet18-f37072fd.pth
# 100%|██████████| 44.7M/44.7M [00:00<00:00, 171MB/s]

# %%
model3=models.resnet18(pretrained=True).to(device)
#Change the first layer of model3 to take in a single channel
model3.conv1 = nn.Conv2d(1, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False).to(device)

# %%
# Hyperparameters
def init_weights(m):
    if isinstance(m, nn.Linear):
        nn.init.xavier_uniform_(m.weight)
        if m.bias is not None:
            nn.init.zeros_(m.bias)

#device='cuda' if torch.cuda.is_available() else 'cpu'
epochs=10
#model = VisionTransformer().to(device)
model2.apply(init_weights)
optimizer = optim.AdamW(model2.parameters(), lr=0.001, weight_decay=0.01)
criterion = nn.CrossEntropyLoss()
scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, 'min', patience=3, factor=0.1)
torch.nn.utils.clip_grad_norm_(model2.parameters(), max_norm=1.0)

best_val_loss = float('inf')
patience = 3
trigger_times = 0



eff_train_loss_list, eff_val_loss_list = [], []
eff_train_accuracy_list, eff_val_accuracy_list = [], []



def train(model, train_loader, criterion, optimizer,device):
    model.train()
    running_loss = 0.0
    correct = 0
    total = 0
    for images, labels in train_loader:
        images, labels = images.to(device), labels.to(device)
        optimizer.zero_grad()
        outputs = model(images)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()
        running_loss += loss.item()
        _, predicted = torch.max(outputs, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()
    return running_loss / len(train_loader), correct / total

def validate(model, loader, criterion,device):
    model.eval()
    running_loss = 0.0
    correct = 0
    total = 0
    with torch.no_grad():
        for images, labels in loader:
            images, labels = images.to(device), labels.to(device)
            outputs = model(images)
            loss = criterion(outputs, labels)
            running_loss += loss.item()
            _, predicted = torch.max(outputs, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()
    return running_loss / len(loader), correct / total

for epoch in range(epochs):
    # Training loop
    train_loss, train_acc = train(model2, train_loader, criterion, optimizer,device)

    # Validation loop
    val_loss, val_acc = validate(model2, val_loader, criterion,device)

    # Append the results
    eff_train_loss_list.append(train_loss)
    eff_train_accuracy_list.append(train_acc)
    eff_val_loss_list.append(val_loss)
    eff_val_accuracy_list.append(val_acc)

    print(f'''EPOCH {epoch}:
     Training: loss = {eff_train_loss_list[-1]:.4f} | accuracy = {eff_train_accuracy_list[-1]:.2f}/100
     Validation: loss = {eff_val_loss_list[-1]:.4f} | accuracy = {eff_val_accuracy_list[-1]:.2f}/100
     ''')
# Out:
# EPOCH 0:
#      Training: loss = 0.1992 | accuracy = 0.97/100
#      Validation: loss = 0.0213 | accuracy = 1.00/100
#
# EPOCH 1:
#      Training: loss = 0.0357 | accuracy = 0.99/100
#      Validation: loss = 0.0179 | accuracy = 1.00/100
#
# EPOCH 2:
#      Training: loss = 0.0314 | accuracy = 0.99/100
#      Validation: loss = 0.0124 | accuracy = 1.00/100
#
# EPOCH 3:
#      Training: loss = 0.0309 | accuracy = 0.99/100
#      Validation: loss = 0.0181 | accuracy = 1.00/100
#
# EPOCH 4:
#      Training: loss = 0.0207 | accuracy = 0.99/100
#      Validation: loss = 0.0198 | accuracy = 1.00/100
#
# EPOCH 5:
#      Training: loss = 0.0184 | accuracy = 0.99/100
#      Validation: loss = 0.0189 | accuracy = 1.00/100
#
# EPOCH 6:
#      Training: loss = 0.0204 | accuracy = 0.99/100
#      Validation: loss = 0.0205 | accuracy = 1.00/100
#
# EPOCH 7:
#      Training: loss = 0.0189 | accuracy = 0.99/100
#      Validation: loss = 0.0184 | accuracy = 0.99/100
#
# EPOCH 8:
# ...

# %%
# Plot model performance accros the epochs
f, ax = plt.subplots(1, 2, figsize=(8, 3))

ax[0].plot(eff_train_loss_list, label='Training loss of efficient')
ax[0].plot(eff_val_loss_list, label='Validation loss of efficient')
ax[0].set_xlabel('Epoch')
ax[0].legend()

ax[1].plot(eff_train_accuracy_list, label='Training accuracy of efficient')
ax[1].plot(eff_val_accuracy_list, label='Validation accuracy of efficient')
ax[1].set_xlabel('Epoch')
ax[1].legend()

f.show()

# %%
# Hyperparameters
def init_weights(m):
    if isinstance(m, nn.Linear):
        nn.init.xavier_uniform_(m.weight)
        if m.bias is not None:
            nn.init.zeros_(m.bias)

#device='cuda' if torch.cuda.is_available() else 'cpu'
epochs=10
num_ftrs = model3.fc.in_features
model3.fc = nn.Linear(num_ftrs, 2).to(device)

model3.apply(init_weights)
optimizer = optim.AdamW(model3.parameters(), lr=0.001, weight_decay=0.01)
criterion = nn.CrossEntropyLoss()
scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, 'min', patience=3, factor=0.1)
torch.nn.utils.clip_grad_norm_(model3.parameters(), max_norm=1.0)

best_val_loss = float('inf')
patience = 3
trigger_times = 0



res_train_loss_list, res_val_loss_list = [], []
res_train_accuracy_list, res_val_accuracy_list = [], []



def train(model, train_loader, criterion, optimizer,device):
    model.train()
    running_loss = 0.0
    correct = 0
    total = 0
    for images, labels in train_loader:
        images, labels = images.to(device), labels.to(device)
        optimizer.zero_grad()
        outputs = model(images)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()
        running_loss += loss.item()
        _, predicted = torch.max(outputs, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()
    return running_loss / len(train_loader), correct / total

def validate(model, loader, criterion,device):
    model.eval()
    running_loss = 0.0
    correct = 0
    total = 0
    with torch.no_grad():
        for images, labels in loader:
            images, labels = images.to(device), labels.to(device)
            outputs = model(images)
            loss = criterion(outputs, labels)
            running_loss += loss.item()
            _, predicted = torch.max(outputs, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()
    return running_loss / len(loader), correct / total

for epoch in range(epochs):
    # Training loop
    train_loss, train_acc = train(model2, train_loader, criterion, optimizer,device)

    # Validation loop
    val_loss, val_acc = validate(model2, val_loader, criterion,device)

    # Append the results
    res_train_loss_list.append(train_loss)
    res_train_accuracy_list.append(train_acc)
    res_val_loss_list.append(val_loss)
    res_val_accuracy_list.append(val_acc)

    print(f'''EPOCH {epoch}:
     Training: loss = {res_train_loss_list[-1]:.4f} | accuracy = {res_train_accuracy_list[-1]:.2f}/100
     Validation: loss = {res_val_loss_list[-1]:.4f} | accuracy = {res_val_accuracy_list[-1]:.2f}/100
     ''')
# Out:
# EPOCH 0:
#      Training: loss = 0.0086 | accuracy = 1.00/100
#      Validation: loss = 0.0194 | accuracy = 1.00/100
#
# EPOCH 1:
#      Training: loss = 0.0087 | accuracy = 1.00/100
#      Validation: loss = 0.0195 | accuracy = 1.00/100
#
# EPOCH 2:
#      Training: loss = 0.0082 | accuracy = 1.00/100
#      Validation: loss = 0.0199 | accuracy = 1.00/100
#
# EPOCH 3:
#      Training: loss = 0.0101 | accuracy = 1.00/100
#      Validation: loss = 0.0194 | accuracy = 1.00/100
#
# EPOCH 4:
#      Training: loss = 0.0106 | accuracy = 1.00/100
#      Validation: loss = 0.0195 | accuracy = 1.00/100
#
# EPOCH 5:
#      Training: loss = 0.0092 | accuracy = 1.00/100
#      Validation: loss = 0.0195 | accuracy = 1.00/100
#
# EPOCH 6:
#      Training: loss = 0.0099 | accuracy = 1.00/100
#      Validation: loss = 0.0196 | accuracy = 1.00/100
#
# EPOCH 7:
#      Training: loss = 0.0100 | accuracy = 1.00/100
#      Validation: loss = 0.0197 | accuracy = 1.00/100
#
# EPOCH 8:
# ...

# %%
# Plot model performance accros the epochs
f, ax = plt.subplots(1, 2, figsize=(8, 3))

ax[0].plot(res_train_loss_list, label='Training loss of resnet')
ax[0].plot(res_val_loss_list, label='Validation loss of resnet')
ax[0].set_xlabel('Epoch')
ax[0].legend()

ax[1].plot(res_train_accuracy_list, label='Training accuracy of resnet')
ax[1].plot(res_val_accuracy_list, label='Validation accuracy of resnet')
ax[1].set_xlabel('Epoch')
ax[1].legend()

f.show()

# %%
from sklearn import metrics


model2.eval()
predictions_list = []
with torch.no_grad():
    for image, label in test_dataset:
        image = image.to(device) # Move image to the device
        # label is already an integer and doesn't need to be moved
        # it will be converted to a tensor during loss calculation if needed


        output = model2(image.unsqueeze(0)) # Get model output
        _, predicted = torch.max(output, 1) # Get the predicted class index
        predictions_list.append(predicted.item())
y_true = np.array([el[1] for el in test_dataset])  # Removed .item()
y_pred_eff = np.array(predictions_list)

confusion_mat = metrics.confusion_matrix(y_true, y_pred_eff)
cm_display = metrics.ConfusionMatrixDisplay(confusion_matrix = confusion_mat, display_labels = [ 'Healthy', 'tumor'])

cm_display.plot()
plt.title("Confusion Matrix for efficient")
# Out:
# Text(0.5, 1.0, 'Confusion Matrix for efficient')

# %%
from sklearn import metrics


model3.eval()
predictions_list = []
with torch.no_grad():
    for image, label in test_dataset:
        image = image.to(device) # Move image to the device
        # label is already an integer and doesn't need to be moved
        # it will be converted to a tensor during loss calculation if needed


        output = model3(image.unsqueeze(0)) # Get model output
        _, predicted = torch.max(output, 1) # Get the predicted class index
        predictions_list.append(predicted.item())
y_true = np.array([el[1] for el in test_dataset])  # Removed .item()
y_pred_res = np.array(predictions_list)

confusion_mat = metrics.confusion_matrix(y_true, y_pred_res)
cm_display = metrics.ConfusionMatrixDisplay(confusion_matrix = confusion_mat, display_labels = [ 'Healthy', 'tumor'])

cm_display.plot()
plt.title("Confusion Matrix for resnet")
# Out:
# Text(0.5, 1.0, 'Confusion Matrix for resnet')

# %%
from sklearn.metrics import precision_score, f1_score, recall_score
accuracy = metrics.accuracy_score(y_true, y_pred_eff)
precision = precision_score(y_true, y_pred_eff)
f1 = f1_score(y_true, y_pred_eff)
recall = recall_score(y_true, y_pred_eff)

print(f"Accuracy efficient: {accuracy:.4f}")
print(f"Precision efficient: {precision:.4f}")
print(f"F1-score efficient: {f1:.4f}")
print(f"Recall efficient: {recall:.4f}")
# Out:
# Accuracy efficient: 0.9969
# Precision efficient: 0.9980
# F1-score efficient: 0.9970
# Recall efficient: 0.9960

# %%
from sklearn.metrics import precision_score, f1_score, recall_score
accuracy = metrics.accuracy_score(y_true, y_pred_res)
precision = precision_score(y_true, y_pred_res)
f1 = f1_score(y_true, y_pred_res)
recall = recall_score(y_true, y_pred_res)

print(f"Accuracy resnet: {accuracy:.4f}")
print(f"Precision resnet: {precision:.4f}")
print(f"F1-score resnet: {f1:.4f}")
print(f"Recall resnet: {recall:.4f}")
# Out:
# Accuracy resnet: 0.5198
# Precision resnet: 0.5198
# F1-score resnet: 0.6840
# Recall resnet: 1.0000

# %%
def train_model(model, train_loader, val_loader, num_epochs=10, model_name='model'):
    optimizer = torch.optim.AdamW(model.parameters(), lr=1e-4)
    scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=num_epochs)
    best_acc = 0.0

    for epoch in range(num_epochs):
        # Training phase
        model.train()
        for images, labels in train_loader:
            images, labels = images.to(device), labels.to(device)
            optimizer.zero_grad()
            outputs = model(images)
            loss = F.cross_entropy(outputs, labels)
            loss.backward()
            optimizer.step()

        # Validation phase
        model.eval()
        val_correct = 0
        with torch.no_grad():
            for images, labels in val_loader:
                images, labels = images.to(device), labels.to(device)
                outputs = model(images)
                val_correct += (outputs.argmax(1) == labels).sum().item()

        val_acc = val_correct / len(val_loader.dataset)
        if val_acc > best_acc:
            torch.save(model.state_dict(), f'best_{model_name}.pth')
            best_acc = val_acc

        scheduler.step()
        print(f'{model_name} Epoch {epoch+1}/{num_epochs}, Val Acc: {val_acc:.4f}')

# %%
# Train all base models
train_model(model1, train_loader, val_loader, num_epochs=10, model_name='vit_base')
train_model(model2, train_loader, val_loader, num_epochs=10, model_name='efficient_bo')
train_model(model3, train_loader, val_loader, num_epochs=10, model_name='resnet')
# Out:
# vit_base Epoch 1/10, Val Acc: 0.9906
# vit_base Epoch 2/10, Val Acc: 0.9886
# vit_base Epoch 3/10, Val Acc: 0.9917
# vit_base Epoch 4/10, Val Acc: 0.9865
# vit_base Epoch 5/10, Val Acc: 0.9927
# vit_base Epoch 6/10, Val Acc: 0.9906
# vit_base Epoch 7/10, Val Acc: 0.9917
# vit_base Epoch 8/10, Val Acc: 0.9927
# vit_base Epoch 9/10, Val Acc: 0.9958
# vit_base Epoch 10/10, Val Acc: 0.9969
# efficient_bo Epoch 1/10, Val Acc: 0.9979
# efficient_bo Epoch 2/10, Val Acc: 0.9979
# efficient_bo Epoch 3/10, Val Acc: 0.9979
# efficient_bo Epoch 4/10, Val Acc: 0.9979
# efficient_bo Epoch 5/10, Val Acc: 0.9979
# efficient_bo Epoch 6/10, Val Acc: 0.9979
# efficient_bo Epoch 7/10, Val Acc: 0.9979
# efficient_bo Epoch 8/10, Val Acc: 0.9979
# efficient_bo Epoch 9/10, Val Acc: 0.9979
# efficient_bo Epoch 10/10, Val Acc: 0.9979
# resnet Epoch 1/10, Val Acc: 0.9979
# resnet Epoch 2/10, Val Acc: 0.9979
# resnet Epoch 3/10, Val Acc: 0.9979
# resnet Epoch 4/10, Val Acc: 0.9979
# ...

# %%
# Save the trained models to your Google Drive
# !cp best_vit_base.pth /content/drive/MyDrive/
# !cp best_efficient_bo.pth /content/drive/MyDrive/
# !cp best_resnet.pth /content/drive/MyDrive/

# %%
# Load trained models
model1.load_state_dict(torch.load('/content/drive/MyDrive/best_vit_base.pth')) # Load vit_base state_dict into model1
model2.load_state_dict(torch.load('/content/drive/MyDrive/best_efficient_bo.pth')) # Load efficient_bo state_dict into model2
model3.load_state_dict(torch.load('/content/drive/MyDrive/best_resnet.pth')) # Load resnet state_dict into model3

models = [model1, model2, model3]

# Create ensemble
ensemble = EnsembleModel(models=models, ensemble_method='weighted').to(device)

# %%
from sklearn.metrics import (
    roc_auc_score,
    precision_score,
    recall_score,
    f1_score,
    confusion_matrix,
    ConfusionMatrixDisplay
)
import matplotlib.pyplot as plt

def evaluate_ensemble(ensemble, test_loader):
    ensemble.eval()
    all_labels = []
    all_preds = []
    all_probs = []

    with torch.no_grad():
        for images, labels in test_loader:
            images, labels = images.to(device), labels.to(device)
            outputs = ensemble(images)

            # Get predicted class and probabilities
            probs = F.softmax(outputs, dim=1)  # Softmax for probabilities
            preds = torch.argmax(outputs, dim=1)  # Predicted class

            # Store results
            all_labels.extend(labels.cpu().numpy())
            all_preds.extend(preds.cpu().numpy())
            all_probs.extend(probs.cpu().numpy())

    # Convert to numpy arrays
    all_labels = np.array(all_labels)
    all_preds = np.array(all_preds)
    all_probs = np.array(all_probs)

    # Calculate metrics
    accuracy = (all_preds == all_labels).mean()
    roc_auc = roc_auc_score(all_labels, all_probs[:, 1])  # For binary classification
    precision = precision_score(all_labels, all_preds)
    recall = recall_score(all_labels, all_preds)
    f1 = f1_score(all_labels, all_preds)

    # Print metrics
    print(f"Accuracy: {accuracy:.4f}")
    print(f"ROC-AUC: {roc_auc:.4f}")
    print(f"Precision: {precision:.4f}")
    print(f"Recall: {recall:.4f}")
    print(f"F1-Score: {f1:.4f}")

    # Confusion Matrix
    cm = confusion_matrix(all_labels, all_preds)
    disp = ConfusionMatrixDisplay(confusion_matrix=cm,display_labels = [ 'Healthy', 'tumor'])
    disp.plot(cmap=plt.cm.Blues)
    plt.title("Confusion Matrix")
    plt.show()

    return {
        "accuracy": accuracy,
        "roc_auc": roc_auc,
        "precision": precision,
        "recall": recall,
        "f1_score": f1,
        "confusion_matrix": cm
    }

# Evaluate ensemble
metrics = evaluate_ensemble(ensemble, test_loader)
# Out:
# Accuracy: 0.9969
# ROC-AUC: 0.9993
# Precision: 0.9980
# Recall: 0.9960
# F1-Score: 0.9970

# %%
def predict_image_class(image_path, ensemble, transform, device, mean, std): # Add mean and std as arguments
    """
    Predicts the class of an image using the ensemble model.
    """
    try:
        # Load and preprocess the image
        img = cv2.imread(image_path)
        img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY) # Convert to grayscale
        img = cv2.resize(img, (224, 224))

        # Create a transform with normalization using the provided mean and std
        normalize = transforms.Normalize(mean=mean, std=std)
        inference_transform = transforms.Compose([
            transforms.ToTensor(),
            normalize
        ])

        img = inference_transform(img).unsqueeze(0).to(device) # Add batch dimension and move to device

        # Prediction logic
        with torch.no_grad():
            outputs = ensemble(img)
            probs = F.softmax(outputs, dim=1)
            predicted_class = torch.argmax(probs, dim=1).item()

        # Map class indices to class names
        class_names = ['Healthy', 'tumor']
        predicted_class = class_names[predicted_class]

        return predicted_class, confidence  # Return predicted class and confidence

    except Exception as e:
        print(f"Error during prediction: {e}")
        return None, None

# Example usage

image_path = "/content/Y1.jpg"
img = mpimg.imread(image_path)
plt.imshow(img)
plt.axis('off')  # Turn off axis numbers
plt.show()

# Get mean and std from your training data (as you calculated before)
mean = 0.223
std = 0.2428

predicted_class, confidence = predict_image_class(image_path, ensemble, transform, device, mean, std) # Pass mean and std to the function

if predicted_class is not None:
    print(f"Predicted class: {predicted_class}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-87e4c77b96c0> in <cell line: 0>()
#      38
#      39 image_path = "/content/Y1.jpg"
# ---> 40 img = mpimg.imread(image_path)
#      41 plt.imshow(img)
#      42 plt.axis('off')  # Turn off axis numbers
#
# NameError: name 'mpimg' is not defined

# %%
image_path = "/content/2 no.jpeg"
img = mpimg.imread(image_path)
plt.imshow(img)
plt.axis('off')  # Turn off axis numbers
plt.show()

# Get mean and std from your training data (as you calculated before)
mean = 0.223
std = 0.2428

predicted_class, confidence = predict_image_class(image_path, ensemble, transform, device, mean, std) # Pass mean and std to the function

if predicted_class is not None:
    print(f"Predicted class: {predicted_class}")
    print(f"Confidence: {confidence:.4f}")
# Out:
# Predicted class: tumor
# Confidence: 0.7839
